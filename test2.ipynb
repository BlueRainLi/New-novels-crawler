# %%
from functions import *

# %%
id = 2546
url_base = f"https://www.wenku8.net/novel/{id//1000}/{id}/"
data = get_data(f"{url_base}index.htm")
print(str(data))
# Out:
# <Element html at 0x221f60dddb0>

# %%
data.body.cssselect(".vcss")
# Out:
# [<Element td at 0x221f617f2a0>,
#  <Element td at 0x221f617f200>,
#  <Element td at 0x221f617f390>,
#  <Element td at 0x221f617f610>,
#  <Element td at 0x221f617f7a0>,
#  <Element td at 0x221f617f890>,
#  <Element td at 0x221f61284b0>,
#  <Element td at 0x221f6128140>,
#  <Element td at 0x221f6128280>,
#  <Element td at 0x221f6128320>,
#  <Element td at 0x221f61283c0>,
#  <Element td at 0x221f6128500>]
